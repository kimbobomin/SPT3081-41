# %%
import json
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import cv2
from glob import glob 
# import mpl_toolkits.mplot3d

# %%
file = '/home/s2021710880/work/capstone/cross/D02-1-177-3d.json'
jsonf=open(file,'r')
jsondata=jsonf.read()
obj=json.loads(jsondata)

# %%
len(obj['frames'])
# Out:
# 16

# %%
def set_axes_equal(ax: plt.Axes):
    """Set 3D plot axes to equal scale.

    Make axes of 3D plot have equal scale so that spheres appear as
    spheres and cubes as cubes.  Required since `ax.axis('equal')`
    and `ax.set_aspect('equal')` don't work on 3D.
    """
    limits = np.array([
        ax.get_xlim3d(),
        ax.get_ylim3d(),
        ax.get_zlim3d(),
    ])
    origin = np.mean(limits, axis=1)
    radius = 0.5 * np.max(np.abs(limits[:, 1] - limits[:, 0]))
    _set_axes_radius(ax, origin, radius)

def _set_axes_radius(ax, origin, radius):
    x, y, z = origin
    ax.set_xlim3d([x - radius, x + radius])
    ax.set_ylim3d([y - radius, y + radius])
    ax.set_zlim3d([z - radius, z + radius])

# %%
# %matplotlib notebook
keypointa = {0:'Left Eye',1:'Left Ear', 2:'Right Eye', 3:'Right Ear', 4:'Nose'}
keypointb = {0:'Left Palm', 1:'Left Wrist', 2:'Left Elbow',3:'Left Shoulder',4:'Neck',
            5:'Right Shoulder', 6:'Right Elbow', 7:'Right Wrist',8:'Right Palm',}
keypointc = {0:'Neck', 1:'Back', 2:'Waist'}
keypointd = {0:'Left Foot',1:'Left Ankle',2:'Left Knee', 3:'Left Hip',4:'Waist',
            5:'Right Hip', 6:'Right Knee', 7:'Right Ankle', 8:'Right Foot'}    

for j in range(0,15):
        x1 = []
        y1 = []
        z1 = []
        x2 = []
        y2 = []
        z2 = []
        x3 = []
        y3 = []
        z3 = []        
        x4 = []
        y4 = []
        z4 = []       
        for i in range(len(keypointa)):       
            x1.append(obj['frames'][j]['pts'][keypointa[i]]['x'])
            y1.append(obj['frames'][j]['pts'][keypointa[i]]['y'])
            z1.append(obj['frames'][j]['pts'][keypointa[i]]['z'])
#         abprint(obj['frames'][j]['pts'][keypoint[i]])     
        for i in range(len(keypointb)):       
            x2.append(obj['frames'][j]['pts'][keypointb[i]]['x'])
            y2.append(obj['frames'][j]['pts'][keypointb[i]]['y'])
            z2.append(obj['frames'][j]['pts'][keypointb[i]]['z'])             
        for i in range(len(keypointc)):       
            x3.append(obj['frames'][j]['pts'][keypointc[i]]['x'])
            y3.append(obj['frames'][j]['pts'][keypointc[i]]['y'])
            z3.append(obj['frames'][j]['pts'][keypointc[i]]['z'])    
        for i in range(len(keypointd)):       
            x4.append(obj['frames'][j]['pts'][keypointd[i]]['x'])
            y4.append(obj['frames'][j]['pts'][keypointd[i]]['y'])
            z4.append(obj['frames'][j]['pts'][keypointd[i]]['z'])                                            
                                                                                                
        fig = plt.figure()
        ax = fig.add_subplot(111, projection='3d')
        ax.view_init(20, 90)
        ax.plot(x1, z1, y1, marker = 'o')
        ax.plot(x2, z2, y2, marker = 'o')
        ax.plot(x3, z3, y3, marker = 'o')
        ax.plot(x4, z4, y4, marker = 'o')        
        ax.set_xlabel('x')
        ax.set_ylabel('y')
        ax.set_zlabel('z')    
        ax.set_xlim(-75,100)
        ax.set_ylim(-100,75)
        ax.set_zlim(0,200)
        set_axes_equal(ax)

        plt.savefig('./cross_f/{}.jpg'.format(j))

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import mpl_toolkits.mplot3d.axes3d as p3

fig = plt.figure()
ax = p3.Axes3D(fig)
ax.view_init(20, 90)

def update(frames):
    ax.cla()
    
    j = frames
    
    x1 = []
    y1 = []
    z1 = []
    x2 = []
    y2 = []
    z2 = []
    x3 = []
    y3 = []
    z3 = []        
    x4 = []
    y4 = []
    z4 = []       
    for i in range(len(keypointa)):       
        x1.append(obj['frames'][j]['pts'][keypointa[i]]['x'])
        y1.append(obj['frames'][j]['pts'][keypointa[i]]['y'])
        z1.append(obj['frames'][j]['pts'][keypointa[i]]['z'])
#         abprint(obj['frames'][j]['pts'][keypoint[i]])     
    for i in range(len(keypointb)):       
        x2.append(obj['frames'][j]['pts'][keypointb[i]]['x'])
        y2.append(obj['frames'][j]['pts'][keypointb[i]]['y'])
        z2.append(obj['frames'][j]['pts'][keypointb[i]]['z'])             
    for i in range(len(keypointc)):       
        x3.append(obj['frames'][j]['pts'][keypointc[i]]['x'])
        y3.append(obj['frames'][j]['pts'][keypointc[i]]['y'])
        z3.append(obj['frames'][j]['pts'][keypointc[i]]['z'])    
    for i in range(len(keypointd)):       
        x4.append(obj['frames'][j]['pts'][keypointd[i]]['x'])
        y4.append(obj['frames'][j]['pts'][keypointd[i]]['y'])
        z4.append(obj['frames'][j]['pts'][keypointd[i]]['z']) 

    ax.set_xlim3d(-75,100)
    ax.set_xlabel('X')
    ax.set_ylim(-100,75)
    ax.set_ylabel('Y')
    ax.set_zlim(0,200)
    ax.set_zlabel('Z')
    ax.plot(x1, z1, y1, marker = 'o', color = 'blue')
    ax.plot(x2, z2, y2, marker = 'o', color = 'orange')
    ax.plot(x3, z3, y3, marker = 'o', color = 'green')
    ax.plot(x4, z4, y4, marker = 'o', color = 'red') 

ani = FuncAnimation(fig, update, frames=range(0,15), interval=200)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.8437643016226">

# %%
import os
from PIL import Image
from IPython.display import Image as Img
from IPython.display import display
import glob

# %%
def generate_gif2(path):
    img_list = os.listdir(path)
    img_list = sorted(img_list)
    
    img_list = [path + '/' + x for x in img_list]
    print(img_list)
    
    images = [Image.open(x) for x in img_list]

    im = images[0]
    im.save('out3.gif', save_all=True, append_images=images[1:], loop=0xff, duration=500)
   
    return Img(url='out3.gif') 
    img_resize = Img.resize((148, 148))

# %%
gif2 =generate_gif2('/home/s2021710880/work/capstone/cross_f')
# Out:
# ['/home/s2021710880/work/capstone/cross_f/0.jpg', '/home/s2021710880/work/capstone/cross_f/1.jpg', '/home/s2021710880/work/capstone/cross_f/10.jpg', '/home/s2021710880/work/capstone/cross_f/11.jpg', '/home/s2021710880/work/capstone/cross_f/12.jpg', '/home/s2021710880/work/capstone/cross_f/13.jpg', '/home/s2021710880/work/capstone/cross_f/14.jpg', '/home/s2021710880/work/capstone/cross_f/2.jpg', '/home/s2021710880/work/capstone/cross_f/3.jpg', '/home/s2021710880/work/capstone/cross_f/4.jpg', '/home/s2021710880/work/capstone/cross_f/5.jpg', '/home/s2021710880/work/capstone/cross_f/6.jpg', '/home/s2021710880/work/capstone/cross_f/7.jpg', '/home/s2021710880/work/capstone/cross_f/8.jpg', '/home/s2021710880/work/capstone/cross_f/9.jpg']

# %%
display(gif2)
# Out:
# <img src="out3.gif"/>
